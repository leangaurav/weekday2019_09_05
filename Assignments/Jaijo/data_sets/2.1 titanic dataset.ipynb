# %% [markdown]
# |Variable|Definition|Key|
# |---|---|---|
# |survival|Survival|0 = No, 1 = Yes|
# |pclass|Ticket class|1 = 1st, 2 = 2nd, 3 = 3rd|
# |gender|gender ||
# |Age |Age in years| |
# |sibsp |number of siblings / spouses aboard|	|
# |parch |number of parents / children aboard| |
# |ticket|Ticket number ||
# |fare | fare| 	|
# |cabin |Cabin number|	|
# |embarked|Port of Embarkation|C = Cherbourg, Q = Queenstown, S = Southampton|
# |boat | Lifeboat||
# |body | Body Identification Number||
# |home.dest| Home/destination||

# %% [markdown]
# - Read data and describe it
# - Find columns with missingdata
# - Print shape of dataset
# - drop columns with more than 25% missing data
# - drop columns having independent values(which do not affect the survival rate).
#
#
# - check data types of all columns
# - convert price to numeric
# - find columns still having missing/na values and also count of missing data
# - fill na with mean for fare and age column column.
# - drop na values for embarked column.
# - dump the dataframe to a csv file 'titanic_filtered.csv'.
#
#
# - for surviced column replace 0 with D and 1 with A
# - find the frequency of different values in survived column
# - group by gender and survived and see the counts in each category
# - find different pclass and no of people in each class
#
# - find top 5 people with highest values of age. Count no of male and females in the top 5
# - find max age male and female who survived
# - get average age by gender
# - get average age by people survived vs not-survived

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# 5              5       1         1
# 6              6       1         1
# 7              7       1         0
# 8              8       1         1
# 9              9       1         0
# 10            10       1         0
# 11            11       1         1
# 12            12       1         1
# 13            13       1         1
# 14            14       1         1
# 15            15       1         0
# 16            16       1         0
# 17            17       1         1
# 18            18       1         1
# 19            19       1         0
# 20            20       1         1
# 21            21       1         1
# 22            22       1         1
# 23            23       1         1
# 24            24       1         1
# ...

# %%
df.describe(include= "all")
# Out:
#          Unnamed: 0       pclass     survived                  name gender  \
# count   1309.000000  1309.000000  1309.000000                  1309   1309
# unique          NaN          NaN          NaN                  1307      2
# top             NaN          NaN          NaN  Connolly, Miss. Kate   male
# freq            NaN          NaN          NaN                     2    843
# mean     654.000000     2.294882     0.381971                   NaN    NaN
# std      378.020061     0.837836     0.486055                   NaN    NaN
# min        0.000000     1.000000     0.000000                   NaN    NaN
# 25%      327.000000     2.000000     0.000000                   NaN    NaN
# 50%      654.000000     3.000000     0.000000                   NaN    NaN
# 75%      981.000000     3.000000     1.000000                   NaN    NaN
# max     1308.000000     3.000000     1.000000                   NaN    NaN
#
# ...

# %%
df.count()# counts numbers of data availabe in the all rows of each colunms
# Out:
# Unnamed: 0    1309
# pclass        1309
# survived      1309
# name          1309
# gender        1309
# age           1046
# sibsp         1309
# parch         1309
# ticket        1309
# fare          1308
# cabin          295
# embarked      1307
# boat           486
# body           121
# home.dest      745
# dtype: int64

# %%
# drop column which are not required

# %%
print(df.columns)
# inplace modifies the original data and thresh gives the requried amount of data
#print(df1.columns)
df1 = df.dropna(axis=1,thresh =(1309*0.75),inplace =True)
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'embarked'],
#       dtype='object')

# %%
df.drop(columns =['Unnamed: 0','name','ticket'],inplace =True)
print(df.count())
print(df.shape)
# Out:
# pclass      1309
# survived    1309
# gender      1309
# age         1046
# sibsp       1309
# parch       1309
# fare        1308
# embarked    1307
# dtype: int64
# (1309, 8)

# %%
df.dtypes
# Out:
# pclass        int64
# survived      int64
# gender       object
# age         float64
# sibsp         int64
# parch         int64
# fare         object
# embarked     object
# dtype: object

# %%
# to remove symbols

# %%
#print(dir(df.fare))
print(dir(df.fare))
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_SLICEMAP', '__abs__', '__add__', '__and__', '__array__', '__array_prepare__', '__array_priority__', '__array_wrap__', '__bool__', '__bytes__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__rdivmo
# ...

# %%
#df.fare.replace(r"\$"," ",regex =True, inplace =True)# want to replace $ but using \$ as only"$" it represent end with in "regular expression"
df.fare.replace(r"\$"," ",regex =True,inplace=True)
df.head()
# Out:
#    pclass  survived  gender      age  sibsp  parch      fare embarked
# 0       1         1  female  29.0000      0      0   211.34         S
# 1       1         1    male   0.9167      1      2   151.55         S
# 2       1         0  female   2.0000      1      2   151.55         S
# 3       1         0    male  30.0000      1      2   151.55         S
# 4       1         0  female  25.0000      1      2   151.55         S

# %%
df.shape
# Out:
# (1309, 8)

# %%
df.dtypes# check the data type (its showing object so need to convert in to float)
# Out:
# pclass        int64
# survived      int64
# gender       object
# age         float64
# sibsp         int64
# parch         int64
# fare         object
# embarked     object
# dtype: object

# %%
df.fare = df.fare.astype('float64')# converting in to float

# %%
df.dtypes
# Out:
# pclass        int64
# survived      int64
# gender       object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# dtype: object

# %%
df.head()
# Out:
#    pclass  survived  gender      age  sibsp  parch    fare embarked
# 0       1         1  female  29.0000      0      0  211.34        S
# 1       1         1    male   0.9167      1      2  151.55        S
# 2       1         0  female   2.0000      1      2  151.55        S
# 3       1         0    male  30.0000      1      2  151.55        S
# 4       1         0  female  25.0000      1      2  151.55        S

# %%
df.isna().any()
# Out:
# pclass      False
# survived    False
# gender      False
# age          True
# sibsp       False
# parch       False
# fare         True
# embarked     True
# dtype: bool

# %%
#df.age.fillna(df.age.mean(), inplace =True)
df.age.fillna(df.age.mean(),inplace =True)

# %%
df.isna().any()
# Out:
# pclass      False
# survived    False
# gender      False
# age         False
# sibsp       False
# parch       False
# fare         True
# embarked     True
# dtype: bool

# %%
df.fare.fillna(df.fare.mean(), inplace =True)

# %%
print(df.isna().any())
df.count()
# Out:
# pclass      False
# survived    False
# gender      False
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# dtype: bool
# pclass      1309
# survived    1309
# gender      1309
# age         1309
# sibsp       1309
# parch       1309
# fare        1309
# embarked    1307
# dtype: int64

# %%
df.shape
# Out:
# (1309, 8)

# %%
df.count()
# Out:
# pclass      1309
# survived    1309
# gender      1309
# age         1309
# sibsp       1309
# parch       1309
# fare        1309
# embarked    1307
# dtype: int64

# %%
df.dropna(inplace=True)# deleted the 2 rows in which embarked having na cell,so  count =1307

# %%
df.isna().any()
# Out:
# pclass      False
# survived    False
# gender      False
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked    False
# dtype: bool

# %%
df.shape
# Out:
# (1307, 8)

# %%
df.to_csv('titanic_result.csv')

# %%
# %pwd
# Out:
# 'C:\\Users\\Jaijo Johnson'

# %%
df.head()
# Out:
#    pclass  survived  gender      age  sibsp  parch    fare embarked
# 0       1         1  female  29.0000      0      0  211.34        S
# 1       1         1    male   0.9167      1      2  151.55        S
# 2       1         0  female   2.0000      1      2  151.55        S
# 3       1         0    male  30.0000      1      2  151.55        S
# 4       1         0  female  25.0000      1      2  151.55        S

# %%
df.survived.replace({0: 'D', 1: 'A'},inplace= True)
#                   or
#df.survived.replace(0,"D",inplace=True)
#df.survived.replace(1,"A",inplace=True)

# %%
df
# Out:
#       pclass survived  gender        age  sibsp  parch    fare embarked
# 0          1        A  female  29.000000      0      0  211.34        S
# 1          1        A    male   0.916700      1      2  151.55        S
# 2          1        D  female   2.000000      1      2  151.55        S
# 3          1        D    male  30.000000      1      2  151.55        S
# 4          1        D  female  25.000000      1      2  151.55        S
# 5          1        A    male  48.000000      0      0   26.55        S
# 6          1        A  female  63.000000      1      0   77.96        S
# 7          1        D    male  39.000000      0      0    0.00        S
# 8          1        A  female  53.000000      2      0   51.48        S
# 9          1        D    male  71.000000      0      0   49.50        C
# 10         1        D    male  47.000000      1      0  227.53        C
# 11         1        A  female  18.000000      1      0  227.53        C
# ...

# %%
df.survived.value_counts()
# Out:
# D    809
# A    498
# Name: survived, dtype: int64

# %%
type(df.survived.value_counts())
# Out:
# pandas.core.series.Series

# %%
df.groupby(['survived','gender'])

# %%
(df.groupby(['survived','gender'])).groups
# Out:
# {('A',
#   'female'): Int64Index([   0,    6,    8,   11,   12,   13,   17,   18,   21,   23,
#              ...
#              1223, 1244, 1247, 1257, 1258, 1260, 1261, 1286, 1290, 1300],
#             dtype='int64', length=337),
#  ('A',
#   'male'): Int64Index([   1,    5,   14,   20,   22,   26,   29,   31,   37,   47,
#              ...
#              1196, 1228, 1232, 1233, 1236, 1238, 1240, 1254, 1256, 1277],
#             dtype='int64', length=161),
#  ('D',
#   'female'): Int64Index([   2,    4,  105,  169,  286,  365,  369,  381,  382,  411,
#              ...
#              1227, 1230, 1231, 1265, 1267, 1273, 1276, 1279, 1304, 1305],
#             dtype='int64', length=127),
#  ('D',
#   'male'): Int64Index([   3,    7,    9,   10,   15,   16,   19,   25,   30,   34,
#              ...
#              1296, 1297, 1298, 1299, 1301, 1302, 1303, 1306, 1307, 1308],
#             dtype='int64', length=682)}

# %%
#(df.groupby(['survived','gender'])).size()
(df.groupby(['survived','gender'])).size()
# Out:
# survived  gender
# A         female    337
#           male      161
# D         female    127
#           male      682
# dtype: int64

# %%
df.head()
# Out:
#    pclass survived  gender      age  sibsp  parch    fare embarked
# 0       1        A  female  29.0000      0      0  211.34        S
# 1       1        A    male   0.9167      1      2  151.55        S
# 2       1        D  female   2.0000      1      2  151.55        S
# 3       1        D    male  30.0000      1      2  151.55        S
# 4       1        D  female  25.0000      1      2  151.55        S

# %%
df.age.sort_values().head()
# Out:
# 763     0.1667
# 747     0.3333
# 1240    0.4167
# 427     0.6667
# 1111    0.7500
# Name: age, dtype: float64

# %%
df.sort_values(by =['age']).head()
# Out:
#       pclass survived  gender     age  sibsp  parch   fare embarked
# 763        3        A  female  0.1667      1      2  20.58        S
# 747        3        D    male  0.3333      0      2  14.40        S
# 1240       3        A    male  0.4167      0      1   8.52        C
# 427        2        A    male  0.6667      1      1  14.50        S
# 1111       3        D    male  0.7500      1      1  13.78        S

# %%
df.sort_values(by =['age'],ascending =False).head()
# Out:
#       pclass survived  gender   age  sibsp  parch   fare embarked
# 14         1        A    male  80.0      0      0  30.00        S
# 61         1        A  female  76.0      1      0  78.85        S
# 1235       3        D    male  74.0      0      0   7.78        S
# 135        1        D    male  71.0      0      0  34.65        C
# 9          1        D    male  71.0      0      0  49.50        C

# %%
idx = df.survived =='A'

# %%
df[idx].head()
# Out:
#    pclass survived  gender      age  sibsp  parch    fare embarked
# 0       1        A  female  29.0000      0      0  211.34        S
# 1       1        A    male   0.9167      1      2  151.55        S
# 5       1        A    male  48.0000      0      0   26.55        S
# 6       1        A  female  63.0000      1      0   77.96        S
# 8       1        A  female  53.0000      2      0   51.48        S

# %%
df[idx].head()
p =  df[idx]
r = p.groupby(['gender'])
print(r.age.max())
# Out:
# gender
# female    76.0
# male      80.0
# Name: age, dtype: float64

# %%
print(r.age.mean())
# Out:
# gender
# female    29.704738
# male      27.446643
# Name: age, dtype: float64

# %%
# %%time
df.to_csv('titanic_Filtered.csv')
# Out:
# Wall time: 22.9 ms
