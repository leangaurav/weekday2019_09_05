# %%
import pandas as pd

# %%
# Read sheet "Australia by Residence" from Australia.xlsx

df = pd.read_excel(r'E:\DataScience\weekday2019_09_05\Assignments\australia.xlsx', sheet_name = 'Australia by Residence' , skiprows = 20)
print(df.head())
print(df.describe(include = 'all'))
print(df.shape)
# Out:
#         Type Coverage          OdName  AREA AreaName   REG          RegName  \
# 0  Emigrants     Both     Afghanistan   935     Asia  5501    Southern Asia
# 1  Emigrants     Both         Albania   908   Europe   925  Southern Europe
# 2  Emigrants     Both         Algeria   903   Africa   912  Northern Africa
# 3  Emigrants     Both  American Samoa   909  Oceania   957        Polynesia
# 4  Emigrants     Both         Andorra   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions     0  ...    80   120    70    80   120    ..
# 1  901   Developed regions     0  ...    30    40    30    30    30    ..
# 2  902  Developing regions    20  ...    20    20    30    40    50    ..
# 3  902  Developing regions    10  ...     0     0     0     0     0    ..
# 4  901   Developed regions     0  ...     0     0     0     0     0    ..
#
#    2010  2011  2012  2013
# 0    ..    ..    ..    ..
# ...

# %%
print(df.columns)
print(df.index)
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
# RangeIndex(start=0, stop=448, step=1)

# %%
#Without skip rows

#We will drop index[0:18] and then use the values of index 19 (rows) as our new column names, and then drop index 19
#After that we will  will convert float data type to int in column names , so that column names does not appear as 1980.0

# %%
# Cleaning the data
# If we don't use skiprows

df1 = pd.read_excel(r'E:\DataScience\weekday2019_09_05\Assignments\australia.xlsx', sheet_name = 'Australia by Residence' )
df1.drop(df1.loc[0:18].index , inplace = True)
df1
# Out:
#      Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 19         Type   Coverage                                             OdName
# 20    Emigrants       Both                                        Afghanistan
# 21    Emigrants       Both                                            Albania
# 22    Emigrants       Both                                            Algeria
# 23    Emigrants       Both                                     American Samoa
# 24    Emigrants       Both                                            Andorra
# 25    Emigrants       Both                                             Angola
# 26    Emigrants       Both                                           Anguilla
# 27    Emigrants       Both                                Antigua and Barbuda
# 28    Emigrants       Both                                          Argentina
# 29    Emigrants       Both                                            Armenia
# ...

# %%
df1.loc[19].values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0,
#        1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0,
#        1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0,
#        2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009, 2010,
#        2011, 2012, 2013], dtype=object)

# %%
# Now renaming index 19 and droping row 19


print(df1.loc[19].values)
print(df1.loc[19])
print(df1.columns)
#df2 = df1.rename(columns = df1.loc[19]) #Works fine with copy 
#When I run this line twice Line 11, i get label indexing error, the code runs fines only first time
#Doubt
#When I don't create a copy and makes inplace True, and runs the code Twice Line 11, I get label indexing error
df1.rename(columns = df1.loc[19], inplace= True) #Works fine for the first time
print(df2.columns)
print(df1.columns)

#This approach is very bad and confusing :( , skiprows does the job.
# Out:
# ['Type' 'Coverage' 'OdName' 'AREA' 'AreaName' 'REG' 'RegName' 'DEV'
#  'DevName' 1980.0 1981.0 1982.0 1983.0 1984.0 1985.0 1986.0 1987.0 1988.0
#  1989.0 1990.0 1991.0 1992.0 1993.0 1994.0 1995.0 1996.0 1997.0 1998.0
#  1999.0 2000.0 2001.0 2002.0 2003.0 2004.0 2005.0 2006.0 2007.0 2008.0
#  2009 2010 2011 2012 2013]
# Type            Type
# Coverage    Coverage
# OdName        OdName
# AREA            AREA
# AreaName    AreaName
# REG              REG
# RegName      RegName
# DEV              DEV
# DevName      DevName
# 1980.0          1980
# 1981.0          1981
# 1982.0          1982
# 1983.0          1983
# 1984.0          1984
# 1985.0          1985
# 1986.0          1986
# 1987.0          1987
# 1988.0          1988
# 1989.0          1989
# 1990.0          1990
# 1991.0          1991
# 1992.0          1992
# 1993.0          1993
# 1994.0          1994
# 1995.0          1995
# 1996.0          1996
# 1997.0          1997
# 1998.0          1998
# 1999.0          1999
# ...

# %%
df1.loc[19]
# Out:
# Type            Type
# Coverage    Coverage
# OdName        OdName
# AREA            AREA
# AreaName    AreaName
# REG              REG
# RegName      RegName
# DEV              DEV
# DevName      DevName
# 1980.0          1980
# 1981.0          1981
# 1982.0          1982
# 1983.0          1983
# 1984.0          1984
# 1985.0          1985
# 1986.0          1986
# 1987.0          1987
# 1988.0          1988
# 1989.0          1989
# 1990.0          1990
# 1991.0          1991
# 1992.0          1992
# 1993.0          1993
# 1994.0          1994
# 1995.0          1995
# 1996.0          1996
# 1997.0          1997
# 1998.0          1998
# 1999.0          1999
# 2000.0          2000
# 2001.0          2001
# 2002.0          2002
# 2003.0          2003
# 2004.0          2004
# 2005.0          2005
# 2006.0          2006
# 2007.0          2007
# 2008.0          2008
# 2009            2009
# 2010            2010
# 2011            2011
# 2012            2012
# 2013            2013
# ...

# %%
#Using Rename and filter


# from pandas.api.types import is_numeric_dtype
# list(filter( lambda x : is_numeric_dtype(df1[x]) , df1.columns))
import numpy as np
float_col = list(filter( lambda x : df1[x].dtype == np.float64 , df1.columns))
new_col_df  = [int(f_col) for f_col in float_col]
print(new_col_df)

print(df1.columns.get_loc(1980))
print(df1.columns.get_loc(2008))

old_col = []

for data in df1.iloc[0 , 9:38]:
    old_col.append(data)
    
old_col

df1.rename( columns = dict(zip(old_col ,new_col_df)) , inplace = True)
df1.columns
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# 9
# 37
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
#Change the value from float to int like 1980.0 to 1980 for index 19. beacuse we will keep the values of index 19 as new column 
#names and later drop index 19 itself.
#Doubt

#How will I convert the float dtype of row now into int64?

# print(type(df1.loc[19 , 'Unnamed: 9']))
# df1.loc[19 ,  'Unnamed: 9' : 'Unnamed: 38'] = df1.loc[19 ,  'Unnamed: 9' : 'Unnamed: 38'].apply('int64') 
# print(type(df1.loc[19 , 'Unnamed: 9']))

# #Dosen't convert
# print(df1['Unnamed: 9'][19])

#Leaving this interchange of float to int (Doubt)

#Instead use rename function to change the columns from float to int

# %%
df1
# Out:
#            Type  Coverage                                             OdName  \
# 19         Type  Coverage                                             OdName
# 20    Emigrants      Both                                        Afghanistan
# 21    Emigrants      Both                                            Albania
# 22    Emigrants      Both                                            Algeria
# 23    Emigrants      Both                                     American Samoa
# 24    Emigrants      Both                                            Andorra
# 25    Emigrants      Both                                             Angola
# 26    Emigrants      Both                                           Anguilla
# 27    Emigrants      Both                                Antigua and Barbuda
# 28    Emigrants      Both                                          Argentina
# 29    Emigrants      Both                                            Armenia
# ...

# %%
print(df.describe (include = 'all'))
print(df.shape)
# Out:
#              Type Coverage   OdName        AREA AreaName          REG  \
# count         448      448      448  448.000000      448   448.000000
# unique          2        1      224         NaN        7          NaN
# top     Emigrants     Both  Vanuatu         NaN   Africa          NaN
# freq          224      448        2         NaN      112          NaN
# mean          NaN      NaN      NaN  912.955357      NaN  1208.040179
# std           NaN      NaN      NaN   15.019682      NaN  1109.669573
# min           NaN      NaN      NaN  903.000000      NaN   905.000000
# 25%           NaN      NaN      NaN  903.750000      NaN   914.000000
# 50%           NaN      NaN      NaN  908.000000      NaN   922.000000
# 75%           NaN      NaN      NaN  909.000000      NaN   926.000000
# max           NaN      NaN      NaN  999.000000      NaN  5501.000000
#
#           RegName         DEV             DevName           1980  ...  \
# ...

# %%
print(df.columns.get_loc(2013))

#Finding all the unique values and than droping unnecessarily values
for i in range(38, 43):
    print(df.iloc[:, i].unique())
df.drop(columns = [2009, 2010,2011,2012,2013] , inplace = True)
df.shape
# Out:
# 42
# ['..']
# ['..']
# ['..']
# ['..']
# ['..']
# (448, 38)

# %%
#Cleaning the data, finding  % of NaN values

df.isna().count()
#No NaN present
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1cf0b4795013> in <module>
#       1 #Cleaning the data, finding  % of NaN values
#       2
# ----> 3 df.isna().count()
#       4 #No NaN present
#
# NameError: name 'df' is not defined

# %%
# Describe the dataset
# Use values and index attributes on both Row and Column Indexes
# Check Shape, Datatypes and other attributes and observe the datatype of each columns' data

#Done

# %%
# Delete all Data where the Type = "Emigrants" or Type is not "Immigrants" (Row Deletion)
# Find columns for which more than 50% data is missing and drop them (Column Deletion)
# Drop Unnessary Columns: Type, Coverage, Area, Reg, Dev (Column deletion) Your columns should now look like "OdName,AreaName,RegName,DevName,1980 ... 2008"

# %%
# df = df[df.Type =='Immigrants']

df.drop( df[df.Type == 'Emigrants'].index , axis = 0 , inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-65fe2430b311> in <module>
#       1 # df = df[df.Type =='Immigrants']
#       2
# ----> 3 df.drop( df[df.Type == 'Emigrants'].index , axis = 0 , inplace = True)
#       4 df
#
# NameError: name 'df' is not defined

# %%
miss_val1 = (df.isna().sum() / df.shape[0] ) * 100 > 50
total = df.isna().sum()
df.drop( columns = total[miss_val1].index , axis = 1 , inplace = True)

# df.dropna( thresh = 224 * 0.50, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-029231a8e6a4> in <module>
# ----> 1 miss_val1 = (df.isna().sum() / df.shape[0] ) * 100 > 50
#       2 total = df.isna().sum()
#       3 df.drop( columns = total[miss_val1].index , axis = 1 , inplace = True)
#       4
#       5 # df.dropna( thresh = 224 * 0.50, axis = 1)
#
# NameError: name 'df' is not defined

# %%
df.columns
df.drop( columns = ['Type', 'Coverage', 'AREA', 'REG' , 'DEV' ] , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-15a4ba36fd72> in <module>
# ----> 1 df.columns
#       2 df.drop( columns = ['Type', 'Coverage', 'AREA', 'REG' , 'DEV' ] , inplace = True)
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
# Rename columns :OdName -> Country; RegName -> Region
# Convert Column Names with Int type to Strings to avoid index errors with string indexing "1980, 1981 etc." => " '1980', '1981' ... " (Use rename)
# Find Total number of immigrants for all years, and create a new column Total in data Frame

# %%
df.rename( {'OdName' : 'Country', 'RegName' : 'Region' } , inplace = True , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-65a3c3b7940a> in <module>
# ----> 1 df.rename( {'OdName' : 'Country', 'RegName' : 'Region' } , inplace = True , axis = 1)
#
# NameError: name 'df' is not defined

# %%
print(df.columns)

#First Approach
# df.columns = [str(data) for data in df.columns]
# df.columns

#Second Approach

# new_col = [str(col) for col in df.columns]
# col = df.columns
# df.rename( dict(zip(col, new_col)) , axis = 1 , inplace = True )
# df.columns

#Third approach (Lambda expression)

df.rename(columns = lambda x : str(x) , inplace = True)
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008],
#       dtype='object')
# Index(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008'],
#       dtype='object')

# %%
#Looking for missing values Cleaning again

df1.isna().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7d6096d91366> in <module>
#       1 #Looking for missing values Cleaning again
#       2
# ----> 3 df1.isna().any()
#
# NameError: name 'df1' is not defined

# %%
# Use values and index attributes on both Row and Column Indexes


print(df1.columns.values)
print(df1.index.values)

# Check Shape, Datatypes and other attributes and observe the datatype of each columns' data

print(df1.shape)
print(df1.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-52fd2a2a936d> in <module>
#       2
#       3
# ----> 4 print(df1.columns.values)
#       5 print(df1.index.values)
#       6
#
# NameError: name 'df1' is not defined

# %%
B=pd.DataFrame(data=[[1.0,'1',1],[3.0,7.4,2.0]],columns={1,2.0,3})
# print(B.columns)
print(B)
B[1]= B[1].apply(int)
print(B)
# B.loc[0].values
# B.rename( columns = B.loc[1] , inplace = True)
# B.columns
# print(B.loc[0,'B'])
# B.rename(index = str , columns={'B':'B_B'} , inplace = True)
# print(B.loc[0,'B_B'])
# Out:
#    1.0  2.0  3.0
# 0  1.0    1  1.0
# 1  3.0  7.4  2.0
#    1.0  2.0  3.0
# 0    1    1  1.0
# 1    3  7.4  2.0

# %%
G = pd.Series( [1,2,3] , index = ('A' , 'B' , 'C'))
print(G.values)
print(G)
# Out:
# [1 2 3]
# A    1
# B    2
# C    3
# dtype: int64
